# %% [markdown]
# # Analysis
#
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
# %matplotlib notebook

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %%
#setup date frame and put in city names
city_name=[]
country=[]
date=[]
lat=[]
lng=[]
max_temp=[]
humidity=[]
cloudiniss=[]
wind_speed=[]

city_df = pd.DataFrame({"City": city_name,
                        "Cloudiness":cloudiniss,
                        "Country": country,
                        "Date":date,
                        "Humidity": humidity,
                        "Lat": lat,
                        "Lng": lng,
                        "Max Temp":max_temp,
                        "Wind Speed": wind_speed})
city_df["City"]=cities

city_df.head()
# Out:
#                        City  Cloudiness  Country  Date  Humidity  Lat  Lng  \
# 0             prince rupert         NaN      NaN   NaN       NaN  NaN  NaN
# 1                    nabire         NaN      NaN   NaN       NaN  NaN  NaN
# 2              san patricio         NaN      NaN   NaN       NaN  NaN  NaN
# 3  sao gabriel da cachoeira         NaN      NaN   NaN       NaN  NaN  NaN
# 4                   qaanaaq         NaN      NaN   NaN       NaN  NaN  NaN
#
#    Max Temp  Wind Speed
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN

# %% [markdown]
# # Perform API Calls
#
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set base_url of inquire by city name
base_url = "http://api.openweathermap.org/data/2.5/weather?q="

#start API calls
print("Beginning Data Retrieval")
print("-----------------------------")
record_num =1
for index, row in city_df.iterrows():
    city=row["City"]

    #using city names and set unit to imperial since we need degree in F
    respond = requests.get(f"{base_url}{city}&units=imperial&APPID={api_key}").json()   
    # if the website find the city, save required information in the cell of each roll
    try:
        print(f"Processing Record {index+1} | City name: {city}")
        city_df.loc[index,"Cloudiness"]=respond["clouds"]["all"]
        city_df.loc[index,"Country"]=respond["sys"]["country"]
        city_df.loc[index,"Date"]=respond["dt"]
        city_df.loc[index,"Humidity"]=respond["main"]["humidity"]
        city_df.loc[index,"Lat"]=respond["coord"]["lat"]
        city_df.loc[index,"Lng"]=respond["coord"]["lon"]
        city_df.loc[index,"Max Temp"]=respond["main"]["temp_max"]
        city_df.loc[index,"Wind Speed"]=respond["wind"]["speed"]
        
    #if the webiste cannot find the city, print below message and no information will be saved
    except:
        print(f"Record {index+1} not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | City name: prince rupert
# Processing Record 2 | City name: nabire
# Processing Record 3 | City name: san patricio
# Processing Record 4 | City name: sao gabriel da cachoeira
# Processing Record 5 | City name: qaanaaq
# Processing Record 6 | City name: hilo
# Processing Record 7 | City name: dikson
# Processing Record 8 | City name: albany
# Processing Record 9 | City name: lugovskiy
# Record 9 not found. Skipping...
# Processing Record 10 | City name: calvinia
# Processing Record 11 | City name: porangatu
# Processing Record 12 | City name: khatanga
# Processing Record 13 | City name: rikitea
# Processing Record 14 | City name: leh
# Processing Record 15 | City name: naifaru
# Processing Record 16 | City name: nuuk
# Processing Record 17 | City name: clyde river
# Processing Record 18 | City name: ambulu
# Processing Record 19 | City name: yellowknife
# Processing Record 20 | City name: constitucion
# Processing Record 21 | City name: ushuaia
# Processing Record 22 | City name: saldanha
# Processing Record 23 | City name: bluff
# Processing Record 24 | City name: nikolskoye
# Processing Record 25 | City name: port elizabeth
# Processing Record 26 | City name: aykhal
# Processing Record 27 | City name: faanui
# Processing Record 28 | City name: klaksvik
# Processing Record 29 | City name: mar del plata
# Processing Record 30 | City name: murgab
# Processing Record 31 | City name: sao geraldo do araguaia
# Processing Record 32 | City name: dingle
# Processing Record 33 | City name: puerto ayora
# Processing Record 34 | City name: atuona
# Processing Record 35 | City name: saint george
# Processing Record 36 | City name: busselton
# Processing Record 37 | City name: kaitangata
# Processing Record 38 | City name: inirida
# Processing Record 39 | City name: punta arenas
# Processing Record 40 | City name: castro
# Processing Record 41 | City name: airai
# Processing Record 42 | City name: avarua
# Processing Record 43 | City name: pagman
# Record 43 not found. Skipping...
# Processing Record 44 | City name: onega
# Processing Record 45 | City name: borovichi
# Processing Record 46 | City name: jalu
# Processing Record 47 | City name: eyl
# Processing Record 48 | City name: yatou
# Processing Record 49 | City name: tuktoyaktuk
# Processing Record 50 | City name: kathu
# Processing Record 51 | City name: trairi
# Processing Record 52 | City name: santa rosa
# Processing Record 53 | City name: belushya guba
# Record 53 not found. Skipping...
# Processing Record 54 | City name: jamestown
# Processing Record 55 | City name: sao filipe
# Processing Record 56 | City name: arraial do cabo
# Processing Record 57 | City name: mokhsogollokh
# Processing Record 58 | City name: dargaville
# Processing Record 59 | City name: ribeira grande
# Processing Record 60 | City name: boromo
# Processing Record 61 | City name: mareeba
# Processing Record 62 | City name: san quintin
# Processing Record 63 | City name: vryburg
# Processing Record 64 | City name: masterton
# Processing Record 65 | City name: new norfolk
# Processing Record 66 | City name: beloha
# Processing Record 67 | City name: talnakh
# Processing Record 68 | City name: chulym
# Processing Record 69 | City name: georgetown
# Processing Record 70 | City name: sedelnikovo
# Record 70 not found. Skipping...
# Processing Record 71 | City name: taolanaro
# Record 71 not found. Skipping...
# Processing Record 72 | City name: bredasdorp
# Processing Record 73 | City name: marsberg
# Processing Record 74 | City name: tiksi
# Processing Record 75 | City name: esperance
# Processing Record 76 | City name: codrington
# Processing Record 77 | City name: kavieng
# Processing Record 78 | City name: peace river
# Processing Record 79 | City name: butka
# Processing Record 80 | City name: cape town
# Processing Record 81 | City name: batemans bay
# Processing Record 82 | City name: houma
# Processing Record 83 | City name: mataura
# Processing Record 84 | City name: brae
# Processing Record 85 | City name: durazno
# Processing Record 86 | City name: vardo
# Processing Record 87 | City name: planadas
# Processing Record 88 | City name: kantang
# Processing Record 89 | City name: manokwari
# Processing Record 90 | City name: kapaa
# Processing Record 91 | City name: boende
# Processing Record 92 | City name: hithadhoo
# Processing Record 93 | City name: lasa
# Processing Record 94 | City name: sao joao da barra
# Processing Record 95 | City name: hermanus
# Processing Record 96 | City name: east london
# Processing Record 97 | City name: bani walid
# Processing Record 98 | City name: port hedland
# Processing Record 99 | City name: diffa
# Processing Record 100 | City name: zhigansk
# Processing Record 101 | City name: azimur
# Record 101 not found. Skipping...
# Processing Record 102 | City name: coquimbo
# Processing Record 103 | City name: camacha
# Processing Record 104 | City name: hobart
# Processing Record 105 | City name: port blair
# Processing Record 106 | City name: chokurdakh
# Processing Record 107 | City name: haines junction
# Processing Record 108 | City name: chuy
# Processing Record 109 | City name: mys shmidta
# Record 109 not found. Skipping...
# Processing Record 110 | City name: yerbogachen
# Processing Record 111 | City name: norman wells
# Processing Record 112 | City name: la asuncion
# Processing Record 113 | City name: harwich
# Processing Record 114 | City name: hirara
# Processing Record 115 | City name: kodiak
# Processing Record 116 | City name: aklavik
# Processing Record 117 | City name: bambous virieux
# Processing Record 118 | City name: surt
# Processing Record 119 | City name: luderitz
# Processing Record 120 | City name: paramonga
# Processing Record 121 | City name: mount gambier
# Processing Record 122 | City name: colchester
# Processing Record 123 | City name: butaritari
# Processing Record 124 | City name: saskylakh
# Processing Record 125 | City name: veraval
# Processing Record 126 | City name: kiunga
# Processing Record 127 | City name: kaka
# Processing Record 128 | City name: iracoubo
# Processing Record 129 | City name: udachnyy
# Processing Record 130 | City name: ulladulla
# Processing Record 131 | City name: grand gaube
# Processing Record 132 | City name: monte alegre
# Processing Record 133 | City name: vaasa
# Processing Record 134 | City name: mahebourg
# Processing Record 135 | City name: pedernales
# Processing Record 136 | City name: ambon
# Processing Record 137 | City name: najran
# Processing Record 138 | City name: abastumani
# Processing Record 139 | City name: galgani
# Record 139 not found. Skipping...
# Processing Record 140 | City name: hovd
# Processing Record 141 | City name: zyryanka
# Processing Record 142 | City name: umm kaddadah
# Processing Record 143 | City name: fortuna
# Processing Record 144 | City name: karratha
# Processing Record 145 | City name: samarai
# Processing Record 146 | City name: varna
# Processing Record 147 | City name: nador
# Processing Record 148 | City name: taoudenni
# Processing Record 149 | City name: piopio
# Processing Record 150 | City name: illoqqortoormiut
# Record 150 not found. Skipping...
# Processing Record 151 | City name: cherskiy
# Processing Record 152 | City name: gambo
# Processing Record 153 | City name: ilulissat
# Processing Record 154 | City name: thompson
# Processing Record 155 | City name: port lincoln
# Processing Record 156 | City name: tawnat
# Record 156 not found. Skipping...
# Processing Record 157 | City name: vaini
# Processing Record 158 | City name: uspenka
# Processing Record 159 | City name: lebu
# Processing Record 160 | City name: opuwo
# Processing Record 161 | City name: tsogni
# Processing Record 162 | City name: cruzeiro do sul
# Processing Record 163 | City name: urusha
# Processing Record 164 | City name: katsuura
# Processing Record 165 | City name: tilichiki
# Processing Record 166 | City name: bambanglipuro
# Processing Record 167 | City name: cidreira
# Processing Record 168 | City name: chernyshevskiy
# Processing Record 169 | City name: nizhneyansk
# Record 169 not found. Skipping...
# Processing Record 170 | City name: urumqi
# Record 170 not found. Skipping...
# Processing Record 171 | City name: santarem
# Record 171 not found. Skipping...
# Processing Record 172 | City name: santa helena
# Processing Record 173 | City name: sur
# Processing Record 174 | City name: malanje
# Processing Record 175 | City name: nioro
# Processing Record 176 | City name: lufilufi
# Processing Record 177 | City name: san cristobal
# Processing Record 178 | City name: illapel
# Processing Record 179 | City name: laguna
# Processing Record 180 | City name: avera
# Processing Record 181 | City name: aktash
# Record 181 not found. Skipping...
# Processing Record 182 | City name: palmer
# Processing Record 183 | City name: seymchan
# Processing Record 184 | City name: hattiesburg
# Processing Record 185 | City name: barrow
# Processing Record 186 | City name: amahai
# Processing Record 187 | City name: urucara
# Processing Record 188 | City name: roros
# Processing Record 189 | City name: havre-saint-pierre
# Processing Record 190 | City name: novaky
# Processing Record 191 | City name: longyearbyen
# Processing Record 192 | City name: ofunato
# Processing Record 193 | City name: port alfred
# Processing Record 194 | City name: barentsburg
# Record 194 not found. Skipping...
# Processing Record 195 | City name: chapada dos guimaraes
# Processing Record 196 | City name: xining
# Processing Record 197 | City name: tsihombe
# Record 197 not found. Skipping...
# Processing Record 198 | City name: monte patria
# Processing Record 199 | City name: lakes entrance
# Processing Record 200 | City name: sobolevo
# Processing Record 201 | City name: buchanan
# Processing Record 202 | City name: youghal
# Processing Record 203 | City name: svetlyy
# Record 203 not found. Skipping...
# Processing Record 204 | City name: tasiilaq
# Processing Record 205 | City name: kaspiyskiy
# Processing Record 206 | City name: pokaran
# Processing Record 207 | City name: fort smith
# Processing Record 208 | City name: ust-koksa
# Processing Record 209 | City name: caravelas
# Processing Record 210 | City name: ladario
# Processing Record 211 | City name: hasaki
# Processing Record 212 | City name: sakurai
# Processing Record 213 | City name: beringovskiy
# Processing Record 214 | City name: yulara
# Processing Record 215 | City name: ponta do sol
# Processing Record 216 | City name: viedma
# Processing Record 217 | City name: tumannyy
# Record 217 not found. Skipping...
# Processing Record 218 | City name: kushiro
# Processing Record 219 | City name: bethel
# Processing Record 220 | City name: neuquen
# Processing Record 221 | City name: pokhara
# Processing Record 222 | City name: itupiranga
# Processing Record 223 | City name: pimenta bueno
# Processing Record 224 | City name: upernavik
# Processing Record 225 | City name: rungata
# Record 225 not found. Skipping...
# Processing Record 226 | City name: kahului
# Processing Record 227 | City name: cayenne
# Processing Record 228 | City name: bandarbeyla
# Processing Record 229 | City name: tromso
# Processing Record 230 | City name: sao felix do xingu
# Processing Record 231 | City name: marsh harbour
# Processing Record 232 | City name: lethem
# Processing Record 233 | City name: kichera
# Processing Record 234 | City name: pevek
# Processing Record 235 | City name: saint-philippe
# Processing Record 236 | City name: ketchikan
# Processing Record 237 | City name: sumbawa
# Record 237 not found. Skipping...
# Processing Record 238 | City name: severo-kurilsk
# Processing Record 239 | City name: maldonado
# Processing Record 240 | City name: sorvag
# Record 240 not found. Skipping...
# Processing Record 241 | City name: matay
# Processing Record 242 | City name: safford
# Processing Record 243 | City name: portland
# Processing Record 244 | City name: mecca
# Processing Record 245 | City name: namibe
# Processing Record 246 | City name: port hardy
# Processing Record 247 | City name: goderich
# Processing Record 248 | City name: alyangula
# Processing Record 249 | City name: lingyuan
# Processing Record 250 | City name: sept-iles
# Processing Record 251 | City name: narsaq
# Processing Record 252 | City name: puerto escondido
# Processing Record 253 | City name: kintinku
# Processing Record 254 | City name: krasnoselkup
# Record 254 not found. Skipping...
# Processing Record 255 | City name: pochutla
# Processing Record 256 | City name: urengoy
# Processing Record 257 | City name: bengkulu
# Record 257 not found. Skipping...
# Processing Record 258 | City name: cabo san lucas
# Processing Record 259 | City name: nipawin
# Processing Record 260 | City name: arbuzynka
# Processing Record 261 | City name: erenhot
# Processing Record 262 | City name: porto velho
# Processing Record 263 | City name: kruisfontein
# Processing Record 264 | City name: lompoc
# Processing Record 265 | City name: lesnoy
# Processing Record 266 | City name: kununurra
# Processing Record 267 | City name: lac du bonnet
# Processing Record 268 | City name: victor harbor
# Processing Record 269 | City name: sidney
# Processing Record 270 | City name: rani
# Processing Record 271 | City name: tostamaa
# Record 271 not found. Skipping...
# Processing Record 272 | City name: chapais
# Processing Record 273 | City name: moiyabana
# Record 273 not found. Skipping...
# Processing Record 274 | City name: victoria
# Processing Record 275 | City name: aflu
# Record 275 not found. Skipping...
# Processing Record 276 | City name: umm ruwabah
# Record 276 not found. Skipping...
# Processing Record 277 | City name: bathsheba
# Processing Record 278 | City name: tabuk
# Processing Record 279 | City name: berlevag
# Processing Record 280 | City name: kindu
# Processing Record 281 | City name: leon
# Processing Record 282 | City name: mabaruma
# Processing Record 283 | City name: san carlos de bariloche
# Processing Record 284 | City name: attawapiskat
# Record 284 not found. Skipping...
# Processing Record 285 | City name: praia da vitoria
# Processing Record 286 | City name: domoni
# Record 286 not found. Skipping...
# Processing Record 287 | City name: souillac
# Processing Record 288 | City name: sitka
# Processing Record 289 | City name: vestmannaeyjar
# Processing Record 290 | City name: basoko
# Processing Record 291 | City name: flinders
# Processing Record 292 | City name: meadow lake
# Processing Record 293 | City name: puro
# Processing Record 294 | City name: gornyak
# Processing Record 295 | City name: wittingen
# Processing Record 296 | City name: pacific grove
# Processing Record 297 | City name: winnemucca
# Processing Record 298 | City name: miri
# Processing Record 299 | City name: maxixe
# Processing Record 300 | City name: aljezur
# Processing Record 301 | City name: naugarzan
# Record 301 not found. Skipping...
# Processing Record 302 | City name: lagoa
# Processing Record 303 | City name: vajszlo
# Processing Record 304 | City name: khonuu
# Record 304 not found. Skipping...
# Processing Record 305 | City name: abnub
# Processing Record 306 | City name: ayan
# Processing Record 307 | City name: suntar
# Processing Record 308 | City name: tuatapere
# Processing Record 309 | City name: hervey bay
# Processing Record 310 | City name: grafton
# Processing Record 311 | City name: srednekolymsk
# Processing Record 312 | City name: bolungarvik
# Record 312 not found. Skipping...
# Processing Record 313 | City name: roald
# Processing Record 314 | City name: pointe michel
# Processing Record 315 | City name: zhanaozen
# Processing Record 316 | City name: chicama
# Processing Record 317 | City name: koslan
# Processing Record 318 | City name: sinnamary
# Processing Record 319 | City name: husavik
# Processing Record 320 | City name: tadine
# Processing Record 321 | City name: kuzino
# Processing Record 322 | City name: riyadh
# Processing Record 323 | City name: petropavlovsk-kamchatskiy
# Processing Record 324 | City name: takhatgarh
# Processing Record 325 | City name: san isidro
# Processing Record 326 | City name: tanout
# Processing Record 327 | City name: pimentel
# Processing Record 328 | City name: juifang
# Record 328 not found. Skipping...
# Processing Record 329 | City name: kattivakkam
# Processing Record 330 | City name: sabratah
# Processing Record 331 | City name: natal
# Processing Record 332 | City name: college
# Processing Record 333 | City name: paamiut
# Processing Record 334 | City name: quatre cocos
# Processing Record 335 | City name: saleaula
# Record 335 not found. Skipping...
# Processing Record 336 | City name: matameye
# Record 336 not found. Skipping...
# Processing Record 337 | City name: san jose
# Processing Record 338 | City name: buala
# Processing Record 339 | City name: biak
# Processing Record 340 | City name: cabedelo
# Processing Record 341 | City name: rudbar
# Record 341 not found. Skipping...
# Processing Record 342 | City name: yomitan
# Record 342 not found. Skipping...
# Processing Record 343 | City name: liusha
# Processing Record 344 | City name: salinopolis
# Processing Record 345 | City name: esso
# Processing Record 346 | City name: baruun-urt
# Processing Record 347 | City name: natchitoches
# Processing Record 348 | City name: sand springs
# Processing Record 349 | City name: grand river south east
# Record 349 not found. Skipping...
# Processing Record 350 | City name: the valley
# Processing Record 351 | City name: marsa matruh
# Processing Record 352 | City name: uhlove
# Processing Record 353 | City name: launceston
# Processing Record 354 | City name: bubaque
# Processing Record 355 | City name: ondorhaan
# Record 355 not found. Skipping...
# Processing Record 356 | City name: hearst
# Processing Record 357 | City name: saint-augustin
# Processing Record 358 | City name: coihaique
# Processing Record 359 | City name: pali
# Processing Record 360 | City name: sofiysk
# Record 360 not found. Skipping...
# Processing Record 361 | City name: sterlitamak
# Processing Record 362 | City name: roseburg
# Processing Record 363 | City name: torbay
# Processing Record 364 | City name: lavrentiya
# Processing Record 365 | City name: saucillo
# Processing Record 366 | City name: dulce nombre de culmi
# Processing Record 367 | City name: samusu
# Record 367 not found. Skipping...
# Processing Record 368 | City name: richards bay
# Processing Record 369 | City name: khor
# Processing Record 370 | City name: mangrol
# Processing Record 371 | City name: mount isa
# Processing Record 372 | City name: edd
# Processing Record 373 | City name: rocha
# Processing Record 374 | City name: balkhash
# Processing Record 375 | City name: vallenar
# Processing Record 376 | City name: nome
# Processing Record 377 | City name: broome
# Processing Record 378 | City name: xiuyan
# Processing Record 379 | City name: hambantota
# Processing Record 380 | City name: verkh-usugli
# Processing Record 381 | City name: biltine
# Processing Record 382 | City name: makakilo city
# Processing Record 383 | City name: santa eulalia del rio
# Record 383 not found. Skipping...
# Processing Record 384 | City name: olafsvik
# Record 384 not found. Skipping...
# Processing Record 385 | City name: divnomorskoye
# Processing Record 386 | City name: namatanai
# Processing Record 387 | City name: leningradskiy
# Processing Record 388 | City name: horsham
# Processing Record 389 | City name: tutoia
# Processing Record 390 | City name: akyab
# Record 390 not found. Skipping...
# Processing Record 391 | City name: padang
# Processing Record 392 | City name: tayshet
# Processing Record 393 | City name: vao
# Processing Record 394 | City name: provideniya
# Processing Record 395 | City name: epinal
# Processing Record 396 | City name: pervomayskoye
# Processing Record 397 | City name: novaya bryan
# Processing Record 398 | City name: susah
# Record 398 not found. Skipping...
# Processing Record 399 | City name: ambilobe
# Processing Record 400 | City name: saint-malo
# Processing Record 401 | City name: lorengau
# Processing Record 402 | City name: kopavogur
# Processing Record 403 | City name: abu samrah
# Processing Record 404 | City name: punta gorda
# Processing Record 405 | City name: iisalmi
# Processing Record 406 | City name: kholodnyy
# Processing Record 407 | City name: barawe
# Record 407 not found. Skipping...
# Processing Record 408 | City name: arnprior
# Processing Record 409 | City name: wajima
# Processing Record 410 | City name: vila velha
# Processing Record 411 | City name: harper
# Processing Record 412 | City name: dicabisagan
# Processing Record 413 | City name: khammam
# Processing Record 414 | City name: garowe
# Processing Record 415 | City name: jining
# Processing Record 416 | City name: semey
# Processing Record 417 | City name: birao
# Processing Record 418 | City name: te anau
# Processing Record 419 | City name: aksarka
# Processing Record 420 | City name: bequimao
# Processing Record 421 | City name: bilibino
# Processing Record 422 | City name: ancud
# Processing Record 423 | City name: sakaraha
# Processing Record 424 | City name: marcona
# Record 424 not found. Skipping...
# Processing Record 425 | City name: shkotovo-22
# Record 425 not found. Skipping...
# Processing Record 426 | City name: alice town
# Processing Record 427 | City name: phu ly
# Processing Record 428 | City name: saravan
# Processing Record 429 | City name: matagami
# Processing Record 430 | City name: stranda
# Processing Record 431 | City name: fare
# Processing Record 432 | City name: kedrovyy
# Processing Record 433 | City name: kidal
# Processing Record 434 | City name: bone
# Processing Record 435 | City name: savannah bight
# Processing Record 436 | City name: amderma
# Record 436 not found. Skipping...
# Processing Record 437 | City name: havoysund
# Processing Record 438 | City name: colborne
# Processing Record 439 | City name: walvis bay
# Processing Record 440 | City name: hammerfest
# Processing Record 441 | City name: henties bay
# Processing Record 442 | City name: soe
# Processing Record 443 | City name: kita
# Processing Record 444 | City name: wuning
# Processing Record 445 | City name: mantsala
# Processing Record 446 | City name: gat
# Processing Record 447 | City name: puerto rondon
# Processing Record 448 | City name: los llanos de aridane
# Processing Record 449 | City name: warmbad
# Processing Record 450 | City name: adrar
# Processing Record 451 | City name: port shepstone
# Processing Record 452 | City name: kuzhener
# Processing Record 453 | City name: valparaiso
# Processing Record 454 | City name: anloga
# Processing Record 455 | City name: lolua
# Record 455 not found. Skipping...
# Processing Record 456 | City name: zaysan
# Processing Record 457 | City name: rio grande
# Processing Record 458 | City name: hamilton
# Processing Record 459 | City name: cairns
# Processing Record 460 | City name: oktyabrskoye
# Processing Record 461 | City name: ailigandi
# Processing Record 462 | City name: muisne
# Processing Record 463 | City name: puerto del rosario
# Processing Record 464 | City name: louisbourg
# Record 464 not found. Skipping...
# Processing Record 465 | City name: touros
# Processing Record 466 | City name: kuche
# Record 466 not found. Skipping...
# Processing Record 467 | City name: tautira
# Processing Record 468 | City name: yirol
# Record 468 not found. Skipping...
# Processing Record 469 | City name: sisimiut
# Processing Record 470 | City name: tongliao
# Processing Record 471 | City name: xingyi
# Processing Record 472 | City name: sale
# Processing Record 473 | City name: fairbanks
# Processing Record 474 | City name: starobaltachevo
# Processing Record 475 | City name: giehun
# Processing Record 476 | City name: lagos
# Processing Record 477 | City name: formoso do araguaia
# Record 477 not found. Skipping...
# Processing Record 478 | City name: asau
# Record 478 not found. Skipping...
# Processing Record 479 | City name: omsukchan
# Processing Record 480 | City name: oreanda
# Record 480 not found. Skipping...
# Processing Record 481 | City name: whitehorse
# Processing Record 482 | City name: tukrah
# Record 482 not found. Skipping...
# Processing Record 483 | City name: vostok
# Processing Record 484 | City name: sovetskaya gavan
# Processing Record 485 | City name: itarema
# Processing Record 486 | City name: tignere
# Processing Record 487 | City name: lingao
# Processing Record 488 | City name: vaitupu
# Record 488 not found. Skipping...
# Processing Record 489 | City name: annau
# Processing Record 490 | City name: saint anthony
# Processing Record 491 | City name: dzaoudzi
# Processing Record 492 | City name: hualmay
# Processing Record 493 | City name: nantucket
# Processing Record 494 | City name: tigzirt
# Processing Record 495 | City name: gbarnga
# Processing Record 496 | City name: kalmunai
# Processing Record 497 | City name: carnarvon
# Processing Record 498 | City name: myaundzha
# Processing Record 499 | City name: vanimo
# Processing Record 500 | City name: elko
# Processing Record 501 | City name: ingham
# Processing Record 502 | City name: high rock
# Processing Record 503 | City name: krasnyy chikoy
# Processing Record 504 | City name: manjacaze
# Processing Record 505 | City name: bonavista
# Processing Record 506 | City name: karasburg
# Processing Record 507 | City name: sabang
# Processing Record 508 | City name: nhamunda
# Processing Record 509 | City name: qena
# Processing Record 510 | City name: hendek
# Processing Record 511 | City name: salym
# Processing Record 512 | City name: baykit
# Processing Record 513 | City name: putevka
# Processing Record 514 | City name: haibowan
# Record 514 not found. Skipping...
# Processing Record 515 | City name: wanaka
# Processing Record 516 | City name: high level
# Processing Record 517 | City name: tual
# Processing Record 518 | City name: lubango
# Processing Record 519 | City name: jiddah
# Record 519 not found. Skipping...
# Processing Record 520 | City name: podor
# Processing Record 521 | City name: nerchinskiy zavod
# Processing Record 522 | City name: cockburn town
# Processing Record 523 | City name: tallahassee
# Processing Record 524 | City name: pangnirtung
# Processing Record 525 | City name: den helder
# Processing Record 526 | City name: kirakira
# Processing Record 527 | City name: blagoyevo
# Processing Record 528 | City name: isangel
# Processing Record 529 | City name: armidale
# Processing Record 530 | City name: honiara
# Processing Record 531 | City name: miquelon
# Processing Record 532 | City name: george
# Processing Record 533 | City name: alta floresta
# Processing Record 534 | City name: innisfail
# Processing Record 535 | City name: scarborough
# Processing Record 536 | City name: tres lagoas
# Record 536 not found. Skipping...
# Processing Record 537 | City name: mabayo
# Processing Record 538 | City name: racine
# Processing Record 539 | City name: auki
# Processing Record 540 | City name: manggar
# Processing Record 541 | City name: tando ghulam ali
# Processing Record 542 | City name: pisco
# Processing Record 543 | City name: manavalakurichi
# Processing Record 544 | City name: lundazi
# Processing Record 545 | City name: morrope
# Processing Record 546 | City name: santa teresa
# Processing Record 547 | City name: pavino
# Processing Record 548 | City name: kaeo
# Processing Record 549 | City name: gidole
# Processing Record 550 | City name: doha
# Processing Record 551 | City name: ureki
# Processing Record 552 | City name: pizarro
# Processing Record 553 | City name: umzimvubu
# Record 553 not found. Skipping...
# Processing Record 554 | City name: westport
# Processing Record 555 | City name: nemuro
# Processing Record 556 | City name: tarragona
# Processing Record 557 | City name: shu
# Processing Record 558 | City name: muros
# Processing Record 559 | City name: hillsborough
# Processing Record 560 | City name: castres
# Processing Record 561 | City name: lima
# Processing Record 562 | City name: geraldton
# Processing Record 563 | City name: inta
# Processing Record 564 | City name: namtsy
# Processing Record 565 | City name: komsomolskiy
# Processing Record 566 | City name: tomatlan
# Processing Record 567 | City name: tura
# Processing Record 568 | City name: henderson
# Processing Record 569 | City name: porto novo
# Processing Record 570 | City name: micheldorf
# Processing Record 571 | City name: tahoua
# Processing Record 572 | City name: buin
# Processing Record 573 | City name: cascais
# Processing Record 574 | City name: tuensang
# Processing Record 575 | City name: taltal
# Processing Record 576 | City name: oksfjord
# Processing Record 577 | City name: sentyabrskiy
# Record 577 not found. Skipping...
# Processing Record 578 | City name: hosingen
# Processing Record 579 | City name: hofn
# Processing Record 580 | City name: matamoros
# Processing Record 581 | City name: bakurianis andeziti
# Processing Record 582 | City name: mombasa
# Processing Record 583 | City name: bac lieu
# Record 583 not found. Skipping...
# Processing Record 584 | City name: waslala
# Processing Record 585 | City name: iqaluit
# Processing Record 586 | City name: ruatoria
# Record 586 not found. Skipping...
# Processing Record 587 | City name: acarau
# Record 587 not found. Skipping...

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#data cleaning, drop those cities that cannot be found
city_df=city_df.dropna(how="any")
city_df.count()
# Out:
# City          521
# Cloudiness    521
# Country       521
# Date          521
# Humidity      521
# Lat           521
# Lng           521
# Max Temp      521
# Wind Speed    521
# dtype: int64

# %%
#show dataframe
city_df.head()
# Out:
#                        City  Cloudiness Country          Date  Humidity  \
# 0             prince rupert         1.0      CA  1.536268e+09      82.0
# 1                    nabire        68.0      ID  1.536270e+09      92.0
# 2              san patricio         0.0      PY  1.536270e+09      58.0
# 3  sao gabriel da cachoeira        20.0      BR  1.536264e+09      83.0
# 4                   qaanaaq        68.0      GL  1.536270e+09     100.0
#
#      Lat     Lng  Max Temp  Wind Speed
# 0  54.32 -130.32     59.00        3.36
# 1  -3.36  135.50     66.63        2.19
# 2 -26.98  -56.83     73.47        4.21
# 3  -0.13  -67.09     82.40        4.70
# 4  77.48  -69.36     32.25        3.65

# %%
#reset index and save to a csv file
city_df.reset_index()
city_df.to_csv("Result/City_Data.csv")

# %% [markdown]
# # Plotting the Data
#
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
#draw scatter, set proper size, add grid, title, labels, and save the picture.
lat_temp=plt.scatter(city_df["Lat"],city_df["Max Temp"],s=50,marker="o", facecolors="dodgerblue", edgecolors="black"\
                      ,alpha =0.7)
plt.grid()
plt.title("City Latitude vs Max Temperature (09/06/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("Result/Lat_vs_Temp.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
#draw scatter, set proper size, add grid, title, labels, and save the picture.
lat_humid= plt.scatter(city_df["Lat"],city_df["Humidity"],s=50,marker="o", facecolors="salmon", edgecolors="black"\
                      ,alpha =0.7)
plt.grid()
plt.title("City Latitude vs Humidity (09/06/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
plt.savefig("Result/Lat_vs_Humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
#draw scatter, set proper size, add grid, title, labels, and save the picture.
lat_cloud= plt.scatter(city_df["Lat"],city_df["Cloudiness"],s=50,marker="o", facecolors="blueviolet", edgecolors="black"\
                      ,alpha =0.7)
plt.grid()
plt.title("City Latitude vs Cloudiness (09/06/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()
plt.savefig("Result/Lat_vs_Cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #  Latitude vs. Wind Speed Plot

# %%
#draw scatter, set proper size, add grid, title, labels, and save the picture.
lat_wind= plt.scatter(city_df["Lat"],city_df["Wind Speed"],s=50,marker="o", facecolors="lawngreen", edgecolors="black"\
                      ,alpha =0.7)
plt.grid()
plt.title("City Latitude vs Wind Speed (09/06/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
plt.savefig("Result/Lat_vs_WindSpeed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Observable Trends
# * The closer the latitude of the city to 0 degree, the higher the tempature is.
# * There is no obvious evidence that latitude has an effect on humidity, cloudiness, and wind speed.
# * We can see that the highest tempatures occur at cities located around latitude 30 degree. This because that the date is 09/03. The latitude that receives 90 degree sunshine is still in the north of equator until 9/23.
